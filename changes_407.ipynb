# %%
import pandas as pd
from pathlib import Path

# %%
file_path = Path('..', 'Dataset', 'pre-processed', 'final_breaker_data', 'final_preprocessed_407_data.csv')

# %%
file_path.exists()
# Out:
# True

# %%
df = pd.read_csv(file_path)

# %%
df.head()
# Out:
#    Coil Current C1 (A)  Coil Current C2 (A)  Coil Current C3 (A)  \
# 0                0.000                0.000                0.000
# 1                0.000                0.000                0.000
# 2                0.000                0.000                0.000
# 3                0.029                0.044                0.037
# 4                0.066                0.073                0.066
#
#    Coil Current C4 (A)  Coil Current C5 (A)  Coil Current C6 (A) Unnamed: 6  \
# 0                0.029                  0.0                  0.0
# 1                0.037                  0.0                  0.0
# 2                0.051                  0.0                  0.0
# 3                0.029                  0.0                  0.0
# 4                0.051                  0.0                  0.0
#
#    Contact Travel T1 (mm)  Contact Travel T2 (mm)  Contact Travel T3 (mm)  \
# 0                       0                       0                       0
# 1                       0                       0                       0
# 2                       0                       0                       0
# 3                       0                       0                       0
# 4                       0                       0                       0
#
#    ...  DCRM Res CH6 in uOhm  DCRM Current CH6 in Amp  \
# 0  ...                457.14                        0
# 1  ...                555.80                        0
# 2  ...                555.80                        0
# 3  ...                555.80                        0
# 4  ...                555.80                        0
#
#    CH6 Close-Velocity (m/s)  CH6 Open-Velocity (m/s)  CH6 Test Run  phase  \
# 0                         0                        0           TR2      Y
# 1                         0                        0           TR2      Y
# 2                         0                        0           TR2      Y
# 3                         0                        0           TR2      Y
# 4                         0                        0           TR2      Y
#
#    CH3 Resistance Break CH4 Resistance Break  CH3 Bounce Break  \
# 0                   NaN                  NaN               NaN
# 1                   NaN                  NaN               NaN
# 2                   NaN                  NaN               NaN
# 3                   NaN                  NaN               NaN
# 4                   NaN                  NaN               NaN
#
#    CH4 Bounce Break
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
#
# [5 rows x 48 columns]

# %%
df.drop(columns=['Unnamed: 6'], inplace=True)

# %%
df.head()
# Out:
#    Coil Current C1 (A)  Coil Current C2 (A)  Coil Current C3 (A)  \
# 0                0.000                0.000                0.000
# 1                0.000                0.000                0.000
# 2                0.000                0.000                0.000
# 3                0.029                0.044                0.037
# 4                0.066                0.073                0.066
#
#    Coil Current C4 (A)  Coil Current C5 (A)  Coil Current C6 (A)  \
# 0                0.029                  0.0                  0.0
# 1                0.037                  0.0                  0.0
# 2                0.051                  0.0                  0.0
# 3                0.029                  0.0                  0.0
# 4                0.051                  0.0                  0.0
#
#    Contact Travel T1 (mm)  Contact Travel T2 (mm)  Contact Travel T3 (mm)  \
# 0                       0                       0                       0
# 1                       0                       0                       0
# 2                       0                       0                       0
# 3                       0                       0                       0
# 4                       0                       0                       0
#
#    Contact Travel T4 (mm)  ...  DCRM Res CH6 in uOhm  DCRM Current CH6 in Amp  \
# 0                    0.85  ...                457.14                        0
# 1                   -0.26  ...                555.80                        0
# 2                   -0.02  ...                555.80                        0
# 3                    0.14  ...                555.80                        0
# 4                   -0.02  ...                555.80                        0
#
#    CH6 Close-Velocity (m/s)  CH6 Open-Velocity (m/s)  CH6 Test Run  phase  \
# 0                         0                        0           TR2      Y
# 1                         0                        0           TR2      Y
# 2                         0                        0           TR2      Y
# 3                         0                        0           TR2      Y
# 4                         0                        0           TR2      Y
#
#   CH3 Resistance Break  CH4 Resistance Break  CH3 Bounce Break  \
# 0                  NaN                   NaN               NaN
# 1                  NaN                   NaN               NaN
# 2                  NaN                   NaN               NaN
# 3                  NaN                   NaN               NaN
# 4                  NaN                   NaN               NaN
#
#    CH4 Bounce Break
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
#
# [5 rows x 47 columns]

# %%
df['breaker_id'] = '407'

# %%
df['breaker_id']
# Out:
# 0        407
# 1        407
# 2        407
# 3        407
# 4        407
#         ...
# 13495    407
# 13496    407
# 13497    407
# 13498    407
# 13499    407
# Name: breaker_id, Length: 13500, dtype: str

# %%
df.to_csv(file_path, index=False)
