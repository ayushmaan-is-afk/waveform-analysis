# %%
import pandas as pd
from pathlib import Path

# %%
file_path = Path('..', 'Dataset', 'pre-processed', 'final_breaker_data', 'final_preprocessed_410_data.csv')

# %%
file_path.exists()
# Out:
# True

# %%
df = pd.read_csv(file_path)

# %%
df.head()
# Out:
#    Coil Current C1 (A)  Coil Current C2 (A)  Coil Current C3 (A)  \
# 0                0.000                0.000                0.000
# 1                0.000                0.000                0.000
# 2                0.000                0.022                0.000
# 3                0.044                0.066                0.022
# 4                0.059                0.088                0.044
#
#    Coil Current C4 (A)  Coil Current C5 (A)  Coil Current C6 (A) Unnamed: 6  \
# 0                0.044                  0.0                  0.0
# 1                0.029                  0.0                  0.0
# 2                0.029                  0.0                  0.0
# 3                0.044                  0.0                  0.0
# 4                0.044                  0.0                  0.0
#
#    Contact Travel T1 (mm)  Contact Travel T2 (mm)  Contact Travel T3 (mm)  \
# 0                       0                       0                       0
# 1                       0                       0                       0
# 2                       0                       0                       0
# 3                       0                       0                       0
# 4                       0                       0                       0
#
#    ...  CH5 Open-Velocity (m/s)  CH5 Test Run  DCRM Res CH6 in uOhm  \
# 0  ...                        0           TR2                     0
# 1  ...                        0           TR2                     0
# 2  ...                        0           TR2                     0
# 3  ...                        0           TR2                     0
# 4  ...                        0           TR2                     0
#
#    DCRM Current CH6 in Amp  CH6 Close-Velocity (m/s)  CH6 Open-Velocity (m/s)  \
# 0                        0                         0                        0
# 1                        0                         0                        0
# 2                        0                         0                        0
# 3                        0                         0                        0
# 4                        0                         0                        0
#
#    CH6 Test Run phase CH1 Resistance Break  CH2 Resistance Break
# 0           TR2     B                  NaN                   NaN
# 1           TR2     B                  NaN                   NaN
# 2           TR2     B                  NaN                   NaN
# 3           TR2     B                  NaN                   NaN
# 4           TR2     B                  NaN                   NaN
#
# [5 rows x 48 columns]

# %%
df.drop(columns=['Unnamed: 6'], inplace=True)

# %%
df.head()
# Out:
#    Coil Current C1 (A)  Coil Current C2 (A)  Coil Current C3 (A)  \
# 0                0.000                0.000                0.000
# 1                0.000                0.000                0.000
# 2                0.000                0.022                0.000
# 3                0.044                0.066                0.022
# 4                0.059                0.088                0.044
#
#    Coil Current C4 (A)  Coil Current C5 (A)  Coil Current C6 (A)  \
# 0                0.044                  0.0                  0.0
# 1                0.029                  0.0                  0.0
# 2                0.029                  0.0                  0.0
# 3                0.044                  0.0                  0.0
# 4                0.044                  0.0                  0.0
#
#    Contact Travel T1 (mm)  Contact Travel T2 (mm)  Contact Travel T3 (mm)  \
# 0                       0                       0                       0
# 1                       0                       0                       0
# 2                       0                       0                       0
# 3                       0                       0                       0
# 4                       0                       0                       0
#
#    Contact Travel T4 (mm)  ...  CH5 Open-Velocity (m/s)  CH5 Test Run  \
# 0                    0.44  ...                        0           TR2
# 1                   -0.04  ...                        0           TR2
# 2                    0.12  ...                        0           TR2
# 3                   -0.04  ...                        0           TR2
# 4                   -0.04  ...                        0           TR2
#
#    DCRM Res CH6 in uOhm  DCRM Current CH6 in Amp  CH6 Close-Velocity (m/s)  \
# 0                     0                        0                         0
# 1                     0                        0                         0
# 2                     0                        0                         0
# 3                     0                        0                         0
# 4                     0                        0                         0
#
#    CH6 Open-Velocity (m/s) CH6 Test Run phase  CH1 Resistance Break  \
# 0                        0          TR2     B                   NaN
# 1                        0          TR2     B                   NaN
# 2                        0          TR2     B                   NaN
# 3                        0          TR2     B                   NaN
# 4                        0          TR2     B                   NaN
#
#    CH2 Resistance Break
# 0                   NaN
# 1                   NaN
# 2                   NaN
# 3                   NaN
# 4                   NaN
#
# [5 rows x 47 columns]

# %%
df['breaker_id'] = '410'

# %%
df['breaker_id']
# Out:
# 0        410
# 1        410
# 2        410
# 3        410
# 4        410
#         ...
# 13495    410
# 13496    410
# 13497    410
# 13498    410
# 13499    410
# Name: breaker_id, Length: 13500, dtype: str

# %%
df.to_csv(file_path, index=False)
